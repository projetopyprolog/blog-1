# %% [markdown]
# <a href="https://colab.research.google.com/github/projetopyprolog/blog-1/blob/master/regras_proj_desenv_infantil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Instação e Importação de Bibliotecas

# %%
# !pip install pytholog #importando a biblioteca PythoLog
# Out:
# Collecting pytholog
#   Downloading pytholog-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from pytholog) (10.3.0)
# Downloading pytholog-2.4.1-py3-none-any.whl (16 kB)
# Installing collected packages: pytholog
# Successfully installed pytholog-2.4.1

# %%
import pytholog as pl#importanções internas do pytholog
from collections import OrderedDict #importanções internas do pytholog

# %% [markdown]
# ### Casos de teste

# %% [markdown]
# #### Criança 01 - Caso Adequado

# %%
crianca_01 = {
    'id_crianca': "01",
    'nome': "junior",
    'idade_meses': "4",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 02 -  Caso Alerta

# %%
crianca_02 = {
    'id_crianca': "02",
    'nome': "paulo",
    'idade_meses': "6",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "ausente", #ausente/alerta
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 03 - Caso Atraso

# %%
crianca_03 = {
    'id_crianca': "03",
    'nome': "maria",
    'idade_meses': "4",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "ausente", #marco indicador de atraso de desenvolvimento - faixa etaria anterior
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "ausente", #ausente na faixa etaria da criança
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "ausente", #ausente na faixa etaria da criança
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "nao verificado",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 04 - Caso Atraso

# %%
crianca_04 = {
    'id_crianca': "04",
    'nome': "julia",
    'idade_meses': "6",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "ausente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "ausente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "ausente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "ausente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 05 -  Caso Adequado

# %%
crianca_05 = {
    'id_crianca': "05",
    'nome': "pedro",
    'idade_meses': "3",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 06 - Caso 1 mês - Atraso

# %%
crianca_06 = {
    'id_crianca': "06",
    'nome': "gabriel",
    'idade_meses': "1",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "ausente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 07 - Caso Alerta

# %%
crianca_07 = {
    'id_crianca': "07",
    'nome': "enzo",
    'idade_meses': "6",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "ausente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "ausente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 08 - Caso 1 mês - Adequado

# %%
crianca_08 = {
    'id_crianca': "08",
    'nome': "naiara",
    'idade_meses': "1",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 09 - Caso Atraso

# %%
crianca_09 = {
    'id_crianca': "09",
    'nome': "joao",
    'idade_meses': "5",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "ausente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "ausente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 10 - Caso Alerta

# %%
crianca_10 = {
    'id_crianca': "10",
    'nome': "kleber",
    'idade_meses': "3",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "ausente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "ausente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "ausente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes':"",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 11 - Caso Alerta

# %%
crianca_11 = {
    'id_crianca': "11",
    'nome': "melissa",
    'idade_meses': "2",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "ausente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "",
                'avaliacao': "",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes':"",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 12 - Caso Atraso

# %%
crianca_12 = {
    'id_crianca': "12",
    'nome': "joana",
    'idade_meses': "2",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "ausente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "",
                'avaliacao': "",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "",
                'registro_idade_mes': "",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "",
                'registro_idade_mes':"",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        }
    ]
}

# %% [markdown]
# #### Criança 13 - avançado - adequado

# %%
crianca_13 = {
    'id_crianca': "13",
    'nome': "amanda",
    'idade_meses': "42",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'brinca_esconde_achou': {
                'id_marco': "17",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'transfere_obejetos_mao_para_outra': {
                'id_marco': "18",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'duplica_silabas': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "8",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'senta_sem_apoio': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "9",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'imita_gestos': {
                'id_marco': "20",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'faz_pinca': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "11",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'produz_jargao': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "12",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'anda_com_apoio': {
                'id_marco': "22",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'mostra_oque_quer': {
                'id_marco': "23",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'coloca_blocos_caneca': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'diz_uma_palavra': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'anda_sem_apoio': {
                'id_marco': "25",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'usa_colher_garfo': {
                'id_marco': "26",
                'avaliacao': "presente",
                'registro_idade_mes': "16",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'constroi_torre_dois_cubos': {
                'id_marco': "27",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'fala_tres_palavras': {
                'id_marco': "28",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'anda_para_tras': {
                'id_marco': "29",
                'avaliacao': "presente",
                'registro_idade_mes': "18",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'tira_roupa': {
                'id_marco': "30",
                'avaliacao': "presente",
                'registro_idade_mes': "19",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'constroi_torre_tres_cubos': {
                'id_marco': "31",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'aponta_duas_figuras': {
                'id_marco': "32",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'chuta_bola': {
                'id_marco': "33",
                'avaliacao': "presente",
                'registro_idade_mes': "24",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'veste_se_com_supervisao': {
                'id_marco': "34",
                'avaliacao': "presente",
                'registro_idade_mes': "26",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'constroi_torre_seis_cubos': {
                'id_marco': "35",
                'avaliacao': "presente",
                'registro_idade_mes': "28",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'frases_com_duas_palavras': {
                'id_marco': "36",
                'avaliacao': "presente",
                'registro_idade_mes': "29",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'pula_ambos_pes': {
                'id_marco': "37",
                'avaliacao': "presente",
                'registro_idade_mes': "30",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'brinca_outras_criancas': {
                'id_marco': "38",
                'avaliacao': "presente",
                'registro_idade_mes': "32",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'imita_desenho_linha': {
                'id_marco': "39",
                'avaliacao': "presente",
                'registro_idade_mes': "33",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'reconhece_duas_acoes': {
                'id_marco': "40",
                'avaliacao': "presente",
                'registro_idade_mes': "36",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'arremessa_bola': {
                'id_marco': "41",
                'avaliacao': "presente",
                'registro_idade_mes': "35",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'veste_uma_camiseta': {
                'id_marco': "42",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'move_polegar_mao_fechada': {
                'id_marco': "43",
                'avaliacao': "presente",
                'registro_idade_mes': "39",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'compreende_dois_adjetivos': {
                'id_marco': "44",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'equilibra_em_cada_pe_por_segundo': {
                'id_marco': "45",
                'avaliacao': "presente",
                'registro_idade_mes': "42",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        }
    ]
}

# %% [markdown]
# #### Crianca 14 - avançado - alerta

# %%
crianca_14 = {
    'id_crianca': "14",
    'nome': "jose",
    'idade_meses': "42",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'brinca_esconde_achou': {
                'id_marco': "17",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'transfere_obejetos_mao_para_outra': {
                'id_marco': "18",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'duplica_silabas': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "8",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'senta_sem_apoio': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "9",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'imita_gestos': {
                'id_marco': "20",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'faz_pinca': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "11",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'produz_jargao': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "12",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'anda_com_apoio': {
                'id_marco': "22",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'mostra_oque_quer': {
                'id_marco': "23",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'coloca_blocos_caneca': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'diz_uma_palavra': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'anda_sem_apoio': {
                'id_marco': "25",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'usa_colher_garfo': {
                'id_marco': "26",
                'avaliacao': "presente",
                'registro_idade_mes': "16",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'constroi_torre_dois_cubos': {
                'id_marco': "27",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'fala_tres_palavras': {
                'id_marco': "28",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'anda_para_tras': {
                'id_marco': "29",
                'avaliacao': "presente",
                'registro_idade_mes': "18",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'tira_roupa': {
                'id_marco': "30",
                'avaliacao': "presente",
                'registro_idade_mes': "19",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'constroi_torre_tres_cubos': {
                'id_marco': "31",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'aponta_duas_figuras': {
                'id_marco': "32",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'chuta_bola': {
                'id_marco': "33",
                'avaliacao': "presente",
                'registro_idade_mes': "24",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'veste_se_com_supervisao': {
                'id_marco': "34",
                'avaliacao': "presente",
                'registro_idade_mes': "26",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'constroi_torre_seis_cubos': {
                'id_marco': "35",
                'avaliacao': "presente",
                'registro_idade_mes': "28",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'frases_com_duas_palavras': {
                'id_marco': "36",
                'avaliacao': "presente",
                'registro_idade_mes': "29",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'pula_ambos_pes': {
                'id_marco': "37",
                'avaliacao': "presente",
                'registro_idade_mes': "30",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'brinca_outras_criancas': {
                'id_marco': "38",
                'avaliacao': "presente",
                'registro_idade_mes': "32",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'imita_desenho_linha': {
                'id_marco': "39",
                'avaliacao': "presente",
                'registro_idade_mes': "33",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'reconhece_duas_acoes': {
                'id_marco': "40",
                'avaliacao': "presente",
                'registro_idade_mes': "36",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'arremessa_bola': {
                'id_marco': "41",
                'avaliacao': "presente",
                'registro_idade_mes': "35",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'veste_uma_camiseta': {
                'id_marco': "42",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'move_polegar_mao_fechada': {
                'id_marco': "43",
                'avaliacao': "ausente",
                'registro_idade_mes': "39",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'compreende_dois_adjetivos': {
                'id_marco': "44",
                'avaliacao': "ausente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'equilibra_em_cada_pe_por_segundo': {
                'id_marco': "45",
                'avaliacao': "presente",
                'registro_idade_mes': "42",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        }
    ]
}

# %% [markdown]
# #### Crianca - avançado - atraso

# %%
crianca_15 = {
    'id_crianca': "15",
    'nome': "janaina",
    'idade_meses': "42",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'brinca_esconde_achou': {
                'id_marco': "17",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'transfere_obejetos_mao_para_outra': {
                'id_marco': "18",
                'avaliacao': "ausente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'duplica_silabas': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "8",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'senta_sem_apoio': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "9",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'imita_gestos': {
                'id_marco': "20",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'faz_pinca': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "11",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'produz_jargao': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "12",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'anda_com_apoio': {
                'id_marco': "22",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'mostra_oque_quer': {
                'id_marco': "23",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'coloca_blocos_caneca': {
                'id_marco': "24",
                'avaliacao': "ausente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'diz_uma_palavra': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'anda_sem_apoio': {
                'id_marco': "25",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'usa_colher_garfo': {
                'id_marco': "26",
                'avaliacao': "presente",
                'registro_idade_mes': "16",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'constroi_torre_dois_cubos': {
                'id_marco': "27",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'fala_tres_palavras': {
                'id_marco': "28",
                'avaliacao': "ausente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'anda_para_tras': {
                'id_marco': "29",
                'avaliacao': "presente",
                'registro_idade_mes': "18",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'tira_roupa': {
                'id_marco': "30",
                'avaliacao': "presente",
                'registro_idade_mes': "19",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'constroi_torre_tres_cubos': {
                'id_marco': "31",
                'avaliacao': "ausente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'aponta_duas_figuras': {
                'id_marco': "32",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'chuta_bola': {
                'id_marco': "33",
                'avaliacao': "presente",
                'registro_idade_mes': "24",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'veste_se_com_supervisao': {
                'id_marco': "34",
                'avaliacao': "presente",
                'registro_idade_mes': "26",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'constroi_torre_seis_cubos': {
                'id_marco': "35",
                'avaliacao': "presente",
                'registro_idade_mes': "28",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'frases_com_duas_palavras': {
                'id_marco': "36",
                'avaliacao': "presente",
                'registro_idade_mes': "29",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'pula_ambos_pes': {
                'id_marco': "37",
                'avaliacao': "presente",
                'registro_idade_mes': "30",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'brinca_outras_criancas': {
                'id_marco': "38",
                'avaliacao': "presente",
                'registro_idade_mes': "32",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'imita_desenho_linha': {
                'id_marco': "39",
                'avaliacao': "ausente",
                'registro_idade_mes': "33",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'reconhece_duas_acoes': {
                'id_marco': "40",
                'avaliacao': "ausente",
                'registro_idade_mes': "36",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'arremessa_bola': {
                'id_marco': "41",
                'avaliacao': "presente",
                'registro_idade_mes': "35",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'veste_uma_camiseta': {
                'id_marco': "42",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'move_polegar_mao_fechada': {
                'id_marco': "43",
                'avaliacao': "presente",
                'registro_idade_mes': "39",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'compreende_dois_adjetivos': {
                'id_marco': "44",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'equilibra_em_cada_pe_por_segundo': {
                'id_marco': "45",
                'avaliacao': "presente",
                'registro_idade_mes': "42",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        }
    ]
}

# %% [markdown]
# ### Crianças com todos os marcos

# %% [markdown]
# #### criança 16 - adequado (completo)

# %%
crianca_16 = {
    'id_crianca': "16",
    'nome': "geilson",
    'idade_meses': "72",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'brinca_esconde_achou': {
                'id_marco': "17",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'transfere_obejetos_mao_para_outra': {
                'id_marco': "18",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'duplica_silabas': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "8",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'senta_sem_apoio': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "9",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'imita_gestos': {
                'id_marco': "20",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'faz_pinca': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "11",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'produz_jargao': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "12",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'anda_com_apoio': {
                'id_marco': "22",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'mostra_oque_quer': {
                'id_marco': "23",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'coloca_blocos_caneca': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'diz_uma_palavra': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'anda_sem_apoio': {
                'id_marco': "25",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'usa_colher_garfo': {
                'id_marco': "26",
                'avaliacao': "presente",
                'registro_idade_mes': "16",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'constroi_torre_dois_cubos': {
                'id_marco': "27",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'fala_tres_palavras': {
                'id_marco': "28",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'anda_para_tras': {
                'id_marco': "29",
                'avaliacao': "presente",
                'registro_idade_mes': "18",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'tira_roupa': {
                'id_marco': "30",
                'avaliacao': "presente",
                'registro_idade_mes': "19",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'constroi_torre_tres_cubos': {
                'id_marco': "31",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'aponta_duas_figuras': {
                'id_marco': "32",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'chuta_bola': {
                'id_marco': "33",
                'avaliacao': "presente",
                'registro_idade_mes': "24",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'veste_se_com_supervisao': {
                'id_marco': "34",
                'avaliacao': "presente",
                'registro_idade_mes': "26",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'constroi_torre_seis_cubos': {
                'id_marco': "35",
                'avaliacao': "presente",
                'registro_idade_mes': "28",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'frases_com_duas_palavras': {
                'id_marco': "36",
                'avaliacao': "presente",
                'registro_idade_mes': "29",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'pula_ambos_pes': {
                'id_marco': "37",
                'avaliacao': "presente",
                'registro_idade_mes': "30",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'brinca_outras_criancas': {
                'id_marco': "38",
                'avaliacao': "presente",
                'registro_idade_mes': "32",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'imita_desenho_linha': {
                'id_marco': "39",
                'avaliacao': "presente",
                'registro_idade_mes': "33",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'reconhece_duas_acoes': {
                'id_marco': "40",
                'avaliacao': "presente",
                'registro_idade_mes': "36",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'arremessa_bola': {
                'id_marco': "41",
                'avaliacao': "presente",
                'registro_idade_mes': "35",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'veste_uma_camiseta': {
                'id_marco': "42",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'move_polegar_mao_fechada': {
                'id_marco': "43",
                'avaliacao': "presente",
                'registro_idade_mes': "39",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'compreende_dois_adjetivos': {
                'id_marco': "44",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'equilibra_em_cada_pe_por_um_segundo': {
                'id_marco': "45",
                'avaliacao': "presente",
                'registro_idade_mes': "42",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'emparelha_cores': {
                'id_marco': "46",
                'avaliacao': "presente",
                'registro_idade_mes': "43",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'copia_circulos': {
                'id_marco': "47",
                'avaliacao': "presente",
                'registro_idade_mes': "44",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'fala_clara_compreencivel': {
                'id_marco': "48",
                'avaliacao': "presente",
                'registro_idade_mes': "46",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'pula_em_um_pe_so': {
                'id_marco': "49",
                'avaliacao': "presente",
                'registro_idade_mes': "46",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'veste_se_sem_ajuda': {
                'id_marco': "50",
                'avaliacao': "presente",
                'registro_idade_mes': "49",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'copia_cruz': {
                'id_marco': "51",
                'avaliacao': "presente",
                'registro_idade_mes': "51",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'compreende_quatro_preposicoes': {
                'id_marco': "52",
                'avaliacao': "presente",
                'registro_idade_mes': "52",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'equilibra_em_cada_pe_por_tres_segundo': {
                'id_marco': "53",
                'avaliacao': "presente",
                'registro_idade_mes': "53",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'escova_dentes_sem_ajuda': {
                'id_marco': "54",
                'avaliacao': "presente",
                'registro_idade_mes': "55",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'aponta_linha_mais_comprida': {
                'id_marco': "55",
                'avaliacao': "presente",
                'registro_idade_mes': "56",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'define_cinco_palavras': {
                'id_marco': "56",
                'avaliacao': "presente",
                'registro_idade_mes': "58",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'equilibra_em_cada_pe_por_cinco_segundo': {
                'id_marco': "57",
                'avaliacao': "presente",
                'registro_idade_mes': "59",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'brinca_de_faz_de_conta_com_criancas': {
                'id_marco': "58",
                'avaliacao': "presente",
                'registro_idade_mes': "61",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'desenha_pessoa_com_seis_partes': {
                'id_marco': "59",
                'avaliacao': "presente",
                'registro_idade_mes': "63",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'faz_analogia': {
                'id_marco': "60",
                'avaliacao': "presente",
                'registro_idade_mes': "64",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'marcha_ponta_calcanhar': {
                'id_marco': "61",
                'avaliacao': "presente",
                'registro_idade_mes': "65",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'aceita_segue_regras_nos_jogos_de_mesa': {
                'id_marco': "62",
                'avaliacao': "presente",
                'registro_idade_mes': "67",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'copia_um_quadrado': {
                'id_marco': "63",
                'avaliacao': "presente",
                'registro_idade_mes': "68",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'define_sete_palavras': {
                'id_marco': "63",
                'avaliacao': "presente",
                'registro_idade_mes': "70",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'equilibra_em_cada_pe_por_sete_segundo': {
                'id_marco': "64",
                'avaliacao': "presente",
                'registro_idade_mes': "71",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        }

    ]
}

# %% [markdown]
# #### criança 17 - alerta (completo)

# %%
crianca_17 = {
    'id_crianca': "17",
    'nome': "antonio",
    'idade_meses': "72",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'brinca_esconde_achou': {
                'id_marco': "17",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'transfere_obejetos_mao_para_outra': {
                'id_marco': "18",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'duplica_silabas': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "8",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'senta_sem_apoio': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "9",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'imita_gestos': {
                'id_marco': "20",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'faz_pinca': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "11",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'produz_jargao': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "12",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'anda_com_apoio': {
                'id_marco': "22",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'mostra_oque_quer': {
                'id_marco': "23",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'coloca_blocos_caneca': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'diz_uma_palavra': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'anda_sem_apoio': {
                'id_marco': "25",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'usa_colher_garfo': {
                'id_marco': "26",
                'avaliacao': "presente",
                'registro_idade_mes': "16",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'constroi_torre_dois_cubos': {
                'id_marco': "27",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'fala_tres_palavras': {
                'id_marco': "28",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'anda_para_tras': {
                'id_marco': "29",
                'avaliacao': "presente",
                'registro_idade_mes': "18",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'tira_roupa': {
                'id_marco': "30",
                'avaliacao': "presente",
                'registro_idade_mes': "19",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'constroi_torre_tres_cubos': {
                'id_marco': "31",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'aponta_duas_figuras': {
                'id_marco': "32",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'chuta_bola': {
                'id_marco': "33",
                'avaliacao': "presente",
                'registro_idade_mes': "24",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'veste_se_com_supervisao': {
                'id_marco': "34",
                'avaliacao': "presente",
                'registro_idade_mes': "26",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'constroi_torre_seis_cubos': {
                'id_marco': "35",
                'avaliacao': "presente",
                'registro_idade_mes': "28",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'frases_com_duas_palavras': {
                'id_marco': "36",
                'avaliacao': "presente",
                'registro_idade_mes': "29",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'pula_ambos_pes': {
                'id_marco': "37",
                'avaliacao': "presente",
                'registro_idade_mes': "30",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'brinca_outras_criancas': {
                'id_marco': "38",
                'avaliacao': "presente",
                'registro_idade_mes': "32",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'imita_desenho_linha': {
                'id_marco': "39",
                'avaliacao': "presente",
                'registro_idade_mes': "33",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'reconhece_duas_acoes': {
                'id_marco': "40",
                'avaliacao': "presente",
                'registro_idade_mes': "36",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'arremessa_bola': {
                'id_marco': "41",
                'avaliacao': "presente",
                'registro_idade_mes': "35",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'veste_uma_camiseta': {
                'id_marco': "42",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'move_polegar_mao_fechada': {
                'id_marco': "43",
                'avaliacao': "presente",
                'registro_idade_mes': "39",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'compreende_dois_adjetivos': {
                'id_marco': "44",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'equilibra_em_cada_pe_por_um_segundo': {
                'id_marco': "45",
                'avaliacao': "presente",
                'registro_idade_mes': "42",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'emparelha_cores': {
                'id_marco': "46",
                'avaliacao': "presente",
                'registro_idade_mes': "43",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'copia_circulos': {
                'id_marco': "47",
                'avaliacao': "presente",
                'registro_idade_mes': "44",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'fala_clara_compreencivel': {
                'id_marco': "48",
                'avaliacao': "presente",
                'registro_idade_mes': "46",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'pula_em_um_pe_so': {
                'id_marco': "49",
                'avaliacao': "presente",
                'registro_idade_mes': "46",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'veste_se_sem_ajuda': {
                'id_marco': "50",
                'avaliacao': "presente",
                'registro_idade_mes': "49",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'copia_cruz': {
                'id_marco': "51",
                'avaliacao': "presente",
                'registro_idade_mes': "51",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'compreende_quatro_preposicoes': {
                'id_marco': "52",
                'avaliacao': "presente",
                'registro_idade_mes': "52",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'equilibra_em_cada_pe_por_tres_segundo': {
                'id_marco': "53",
                'avaliacao': "presente",
                'registro_idade_mes': "53",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'escova_dentes_sem_ajuda': {
                'id_marco': "54",
                'avaliacao': "presente",
                'registro_idade_mes': "55",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'aponta_linha_mais_comprida': {
                'id_marco': "55",
                'avaliacao': "presente",
                'registro_idade_mes': "56",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'define_cinco_palavras': {
                'id_marco': "56",
                'avaliacao': "presente",
                'registro_idade_mes': "58",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'equilibra_em_cada_pe_por_cinco_segundo': {
                'id_marco': "57",
                'avaliacao': "presente",
                'registro_idade_mes': "59",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'brinca_de_faz_de_conta_com_criancas': {
                'id_marco': "58",
                'avaliacao': "presente",
                'registro_idade_mes': "61",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'desenha_pessoa_com_seis_partes': {
                'id_marco': "59",
                'avaliacao': "presente",
                'registro_idade_mes': "63",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'faz_analogia': {
                'id_marco': "60",
                'avaliacao': "presente",
                'registro_idade_mes': "64",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'marcha_ponta_calcanhar': {
                'id_marco': "61",
                'avaliacao': "presente",
                'registro_idade_mes': "65",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'aceita_segue_regras_nos_jogos_de_mesa': {
                'id_marco': "62",
                'avaliacao': "presente",
                'registro_idade_mes': "67",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'copia_um_quadrado': {
                'id_marco': "63",
                'avaliacao': "ausente",
                'registro_idade_mes': "68",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'define_sete_palavras': {
                'id_marco': "63",
                'avaliacao': "presente",
                'registro_idade_mes': "70",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'equilibra_em_cada_pe_por_sete_segundo': {
                'id_marco': "64",
                'avaliacao': "presente",
                'registro_idade_mes': "71",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        }

    ]
}

# %% [markdown]
# #### criança 18 - atraso (completo)

# %%
crianca_18 = {
    'id_crianca': "18",
    'nome': "joaquim",
    'idade_meses': "72",
    'marcos': [
        {
            'postura': {
                'id_marco': "01",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'observa_rosto': {
                'id_marco': "02",
                'avaliacao': "não verificado",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'reage_ao_som': {
                'id_marco': "03",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'eleva_cabeca': {
                'id_marco': "04",
                'avaliacao': "presente",
                'registro_idade_mes': "1",
                'limite_superior_faixa_etaria': "1",
                'limite_inferior_faixa_etaria': "1"
            }
        },
        {
            'sorrir_quando_estimulada': {
                'id_marco': "05",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'abre_as_maos': {
                'id_marco': "06",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'emite_sons': {
                'id_marco': "07",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'movimenta_membros': {
                'id_marco': "08",
                'avaliacao': "presente",
                'registro_idade_mes': "2",
                'limite_superior_faixa_etaria': "2",
                'limite_inferior_faixa_etaria': "2"
            }
        },
        {
            'responde_ativamente_contato_social': {
                'id_marco': "09",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'segura_objetos': {
                'id_marco': "10",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'emite_sons_ri_alto': {
                'id_marco': "11",
                'avaliacao': "presente",
                'registro_idade_mes': "4",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'levanta_cabeça_antebraço_bruco': {
                'id_marco': "12",
                'avaliacao': "presente",
                'registro_idade_mes': "3",
                'limite_superior_faixa_etaria': "4",
                'limite_inferior_faixa_etaria': "3"
            }
        },
        {
            'busca_ativa_objetos': {
                'id_marco': "13",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'leva_objetos_boca': {
                'id_marco': "14",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'localiza_som': {
                'id_marco': "15",
                'avaliacao': "presente",
                'registro_idade_mes': "5",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'muda_posicao_rolar': {
                'id_marco': "16",
                'avaliacao': "presente",
                'registro_idade_mes': "6",
                'limite_superior_faixa_etaria': "6",
                'limite_inferior_faixa_etaria': "5"
            }
        },
        {
            'brinca_esconde_achou': {
                'id_marco': "17",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'transfere_obejetos_mao_para_outra': {
                'id_marco': "18",
                'avaliacao': "presente",
                'registro_idade_mes': "7",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'duplica_silabas': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "8",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'senta_sem_apoio': {
                'id_marco': "19",
                'avaliacao': "presente",
                'registro_idade_mes': "9",
                'limite_superior_faixa_etaria': "9",
                'limite_inferior_faixa_etaria': "7"
            }
        },
        {
            'imita_gestos': {
                'id_marco': "20",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'faz_pinca': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "11",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'produz_jargao': {
                'id_marco': "21",
                'avaliacao': "presente",
                'registro_idade_mes': "12",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'anda_com_apoio': {
                'id_marco': "22",
                'avaliacao': "presente",
                'registro_idade_mes': "10",
                'limite_superior_faixa_etaria': "12",
                'limite_inferior_faixa_etaria': "10"
            }
        },
        {
            'mostra_oque_quer': {
                'id_marco': "23",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'coloca_blocos_caneca': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "14",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'diz_uma_palavra': {
                'id_marco': "24",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'anda_sem_apoio': {
                'id_marco': "25",
                'avaliacao': "presente",
                'registro_idade_mes': "15",
                'limite_superior_faixa_etaria': "15",
                'limite_inferior_faixa_etaria': "13"
            }
        },
        {
            'usa_colher_garfo': {
                'id_marco': "26",
                'avaliacao': "presente",
                'registro_idade_mes': "16",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'constroi_torre_dois_cubos': {
                'id_marco': "27",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'fala_tres_palavras': {
                'id_marco': "28",
                'avaliacao': "presente",
                'registro_idade_mes': "17",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'anda_para_tras': {
                'id_marco': "29",
                'avaliacao': "presente",
                'registro_idade_mes': "18",
                'limite_superior_faixa_etaria': "18",
                'limite_inferior_faixa_etaria': "16"
            }
        },
        {
            'tira_roupa': {
                'id_marco': "30",
                'avaliacao': "presente",
                'registro_idade_mes': "19",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'constroi_torre_tres_cubos': {
                'id_marco': "31",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'aponta_duas_figuras': {
                'id_marco': "32",
                'avaliacao': "presente",
                'registro_idade_mes': "23",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'chuta_bola': {
                'id_marco': "33",
                'avaliacao': "presente",
                'registro_idade_mes': "24",
                'limite_superior_faixa_etaria': "24",
                'limite_inferior_faixa_etaria': "19"
            }
        },
        {
            'veste_se_com_supervisao': {
                'id_marco': "34",
                'avaliacao': "presente",
                'registro_idade_mes': "26",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'constroi_torre_seis_cubos': {
                'id_marco': "35",
                'avaliacao': "presente",
                'registro_idade_mes': "28",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'frases_com_duas_palavras': {
                'id_marco': "36",
                'avaliacao': "presente",
                'registro_idade_mes': "29",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'pula_ambos_pes': {
                'id_marco': "37",
                'avaliacao': "presente",
                'registro_idade_mes': "30",
                'limite_superior_faixa_etaria': "30",
                'limite_inferior_faixa_etaria': "25"
            }
        },
        {
            'brinca_outras_criancas': {
                'id_marco': "38",
                'avaliacao': "presente",
                'registro_idade_mes': "32",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'imita_desenho_linha': {
                'id_marco': "39",
                'avaliacao': "presente",
                'registro_idade_mes': "33",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'reconhece_duas_acoes': {
                'id_marco': "40",
                'avaliacao': "presente",
                'registro_idade_mes': "36",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'arremessa_bola': {
                'id_marco': "41",
                'avaliacao': "presente",
                'registro_idade_mes': "35",
                'limite_superior_faixa_etaria': "36",
                'limite_inferior_faixa_etaria': "31"
            }
        },
        {
            'veste_uma_camiseta': {
                'id_marco': "42",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'move_polegar_mao_fechada': {
                'id_marco': "43",
                'avaliacao': "presente",
                'registro_idade_mes': "39",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'compreende_dois_adjetivos': {
                'id_marco': "44",
                'avaliacao': "presente",
                'registro_idade_mes': "38",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'equilibra_em_cada_pe_por_um_segundo': {
                'id_marco': "45",
                'avaliacao': "presente",
                'registro_idade_mes': "42",
                'limite_superior_faixa_etaria': "42",
                'limite_inferior_faixa_etaria': "37"
            }
        },
        {
            'emparelha_cores': {
                'id_marco': "46",
                'avaliacao': "presente",
                'registro_idade_mes': "43",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'copia_circulos': {
                'id_marco': "47",
                'avaliacao': "presente",
                'registro_idade_mes': "44",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'fala_clara_compreencivel': {
                'id_marco': "48",
                'avaliacao': "presente",
                'registro_idade_mes': "46",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'pula_em_um_pe_so': {
                'id_marco': "49",
                'avaliacao': "presente",
                'registro_idade_mes': "46",
                'limite_superior_faixa_etaria': "48",
                'limite_inferior_faixa_etaria': "43"
            }
        },
        {
            'veste_se_sem_ajuda': {
                'id_marco': "50",
                'avaliacao': "presente",
                'registro_idade_mes': "49",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'copia_cruz': {
                'id_marco': "51",
                'avaliacao': "presente",
                'registro_idade_mes': "51",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'compreende_quatro_preposicoes': {
                'id_marco': "52",
                'avaliacao': "presente",
                'registro_idade_mes': "52",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'equilibra_em_cada_pe_por_tres_segundo': {
                'id_marco': "53",
                'avaliacao': "presente",
                'registro_idade_mes': "53",
                'limite_superior_faixa_etaria': "54",
                'limite_inferior_faixa_etaria': "49"
            }
        },
        {
            'escova_dentes_sem_ajuda': {
                'id_marco': "54",
                'avaliacao': "presente",
                'registro_idade_mes': "55",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'aponta_linha_mais_comprida': {
                'id_marco': "55",
                'avaliacao': "presente",
                'registro_idade_mes': "56",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'define_cinco_palavras': {
                'id_marco': "56",
                'avaliacao': "presente",
                'registro_idade_mes': "58",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'equilibra_em_cada_pe_por_cinco_segundo': {
                'id_marco': "57",
                'avaliacao': "presente",
                'registro_idade_mes': "59",
                'limite_superior_faixa_etaria': "60",
                'limite_inferior_faixa_etaria': "55"
            }
        },
        {
            'brinca_de_faz_de_conta_com_criancas': {
                'id_marco': "58",
                'avaliacao': "presente",
                'registro_idade_mes': "61",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'desenha_pessoa_com_seis_partes': {
                'id_marco': "59",
                'avaliacao': "presente",
                'registro_idade_mes': "63",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'faz_analogia': {
                'id_marco': "60",
                'avaliacao': "ausente",
                'registro_idade_mes': "64",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'marcha_ponta_calcanhar': {
                'id_marco': "61",
                'avaliacao': "presente",
                'registro_idade_mes': "65",
                'limite_superior_faixa_etaria': "66",
                'limite_inferior_faixa_etaria': "61"
            }
        },
        {
            'aceita_segue_regras_nos_jogos_de_mesa': {
                'id_marco': "62",
                'avaliacao': "presente",
                'registro_idade_mes': "67",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'copia_um_quadrado': {
                'id_marco': "63",
                'avaliacao': "ausente",
                'registro_idade_mes': "68",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'define_sete_palavras': {
                'id_marco': "63",
                'avaliacao': "ausente",
                'registro_idade_mes': "70",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        },
        {
            'equilibra_em_cada_pe_por_sete_segundo': {
                'id_marco': "64",
                'avaliacao': "presente",
                'registro_idade_mes': "71",
                'limite_superior_faixa_etaria': "72",
                'limite_inferior_faixa_etaria': "67"
            }
        }

    ]
}

# %% [markdown]
# ### Filtragem dos dados das crianças

# %%
#Adicionar as crianças em uma lista
lista_criancas = [crianca_01,crianca_02,crianca_03,crianca_04,crianca_05,crianca_06,crianca_07, crianca_08, crianca_09, crianca_10, crianca_11, crianca_12, crianca_13, crianca_14, crianca_15, crianca_16, crianca_17, crianca_18]
print(*lista_criancas, sep='\n')

#No codigo acima esta adicionando as crianças geradas em uma lista e no print esta mostrando essas crinaças.
# Out:
# {'id_crianca': '01', 'nome': 'junior', 'idade_meses': '4', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '02', 'nome': 'paulo', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'ausente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '03', 'nome': 'maria', 'idade_meses': '4', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'nao verificado', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '04', 'nome': 'julia', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'ausente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '05', 'nome': 'pedro', 'idade_meses': '3', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '06', 'nome': 'gabriel', 'idade_meses': '1', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '07', 'nome': 'enzo', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'ausente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'ausente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '08', 'nome': 'naiara', 'idade_meses': '1', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '09', 'nome': 'joao', 'idade_meses': '5', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '10', 'nome': 'kleber', 'idade_meses': '3', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '11', 'nome': 'melissa', 'idade_meses': '2', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '', 'avaliacao': '', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '12', 'nome': 'joana', 'idade_meses': '2', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '', 'avaliacao': '', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': '', 'registro_idade_mes': '', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '13', 'nome': 'amanda', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco':  ...
# {'id_crianca': '14', 'nome': 'jose', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '2 ...
# {'id_crianca': '15', 'nome': 'janaina', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'ausente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco':  ...
# {'id_crianca': '16', 'nome': 'geilson', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': ...
# {'id_crianca': '17', 'nome': 'antonio', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': ...
# {'id_crianca': '18', 'nome': 'joaquim', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': ...

# %%
def filtro_crianca_idade(crianca):# Filtragem por Idade das regras
  lista_crianca_filtrada = [] #criando uma lista

  # Obtendo a idade da criança
  idade_crianca_meses = int(crianca['idade_meses']) #buscando a idade das crianças da lista de crianças criadas
  crianca_filtrada = crianca.copy() #criando uma copia da lista crinaça para a crianca_filtrada

  for marco in crianca_filtrada['marcos']: #aqui o FOR vai fazer um loop sobre a lista crianca_filtrada
      chave_marco = list(marco.keys())[0] #aqui vai ser lista todos os marcos por chave, ai esta por default o marco 0
      idade_marco_meses = int(marco[chave_marco]['limite_superior_faixa_etaria']) #com o loop dos marcos acima, aqui ira coletar o limite_superior_faixa_etaria de cada marco

      # Verificando se o marco de desenvolvimento é relevante para a idade da criança
      if idade_marco_meses <= idade_crianca_meses: #condição para verificar se o limite_superior_faixa_etaria é menor ou igual a idade da criança
        lista_crianca_filtrada.append(marco) #adicionando o as crinaças filtradas no na lista

  crianca_filtrada['marcos'] = lista_crianca_filtrada #adicionado os marcos a lista
  return crianca_filtrada

#Passando as criança filtradas pela idade

crianca_01_filtrada_idade = filtro_crianca_idade(lista_criancas[0])
print(crianca_01_filtrada_idade)

crianca_02_filtrada_idade = filtro_crianca_idade(lista_criancas[1])
print(crianca_02_filtrada_idade)

crianca_03_filtrada_idade = filtro_crianca_idade(lista_criancas[2])
print(crianca_03_filtrada_idade)

crianca_04_filtrada_idade = filtro_crianca_idade(lista_criancas[3])
print(crianca_04_filtrada_idade)

crianca_05_filtrada_idade = filtro_crianca_idade(lista_criancas[4])
print(crianca_05_filtrada_idade)

crianca_06_filtrada_idade = filtro_crianca_idade(lista_criancas[5])
print(crianca_06_filtrada_idade)

crianca_07_filtrada_idade = filtro_crianca_idade(lista_criancas[6])
print(crianca_07_filtrada_idade)

crianca_08_filtrada_idade = filtro_crianca_idade(lista_criancas[7])
print(crianca_08_filtrada_idade)

crianca_09_filtrada_idade = filtro_crianca_idade(lista_criancas[8])
print(crianca_09_filtrada_idade)

crianca_10_filtrada_idade = filtro_crianca_idade(lista_criancas[9])
print(crianca_10_filtrada_idade)

crianca_11_filtrada_idade = filtro_crianca_idade(lista_criancas[10])
print(crianca_11_filtrada_idade)

crianca_12_filtrada_idade = filtro_crianca_idade(lista_criancas[11])
print(crianca_12_filtrada_idade)

crianca_13_filtrada_idade = filtro_crianca_idade(lista_criancas[12])
print(crianca_13_filtrada_idade)

crianca_14_filtrada_idade = filtro_crianca_idade(lista_criancas[13])
print(crianca_14_filtrada_idade)

crianca_15_filtrada_idade = filtro_crianca_idade(lista_criancas[14])
print(crianca_15_filtrada_idade)

crianca_16_filtrada_idade = filtro_crianca_idade(lista_criancas[15])
print(crianca_16_filtrada_idade)

crianca_17_filtrada_idade = filtro_crianca_idade(lista_criancas[16])
print(crianca_17_filtrada_idade)

crianca_18_filtrada_idade = filtro_crianca_idade(lista_criancas[17])
print(crianca_18_filtrada_idade)
# Out:
# {'id_crianca': '01', 'nome': 'junior', 'idade_meses': '4', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}]}
# {'id_crianca': '02', 'nome': 'paulo', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'ausente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '03', 'nome': 'maria', 'idade_meses': '4', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'nao verificado', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}]}
# {'id_crianca': '04', 'nome': 'julia', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'ausente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '05', 'nome': 'pedro', 'idade_meses': '3', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '06', 'nome': 'gabriel', 'idade_meses': '1', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}]}
# {'id_crianca': '07', 'nome': 'enzo', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'ausente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'ausente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '08', 'nome': 'naiara', 'idade_meses': '1', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}]}
# {'id_crianca': '09', 'nome': 'joao', 'idade_meses': '5', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}]}
# {'id_crianca': '10', 'nome': 'kleber', 'idade_meses': '3', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '11', 'nome': 'melissa', 'idade_meses': '2', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '12', 'nome': 'joana', 'idade_meses': '2', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '13', 'nome': 'amanda', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco':  ...
# {'id_crianca': '14', 'nome': 'jose', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '2 ...
# {'id_crianca': '15', 'nome': 'janaina', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'ausente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco':  ...
# {'id_crianca': '16', 'nome': 'geilson', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': ...
# {'id_crianca': '17', 'nome': 'antonio', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': ...
# {'id_crianca': '18', 'nome': 'joaquim', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'não verificado', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': ...

# %%
def filtro_crianca_avaliacao(crianca):# Filtragem por Avaliação deixando somente as regras que são "presentes" ou "ausentes"

  lista_crianca_filtrada = []
  crianca_filtrada = crianca.copy()
  for marco in crianca_filtrada['marcos']:
      chave_marco = list(marco.keys())[0]
      avaliacao = marco[chave_marco]['avaliacao']
      if avaliacao == "presente" or avaliacao == "ausente":
          lista_crianca_filtrada.append(marco)

  crianca_filtrada['marcos'] = lista_crianca_filtrada
  return crianca_filtrada

#Passando as criança filtradas pela idade para o filtro de avaliaçao

crianca_01_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_01_filtrada_idade)
print(crianca_01_filtrada_idade_avaliacao)

crianca_02_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_02_filtrada_idade)
print(crianca_02_filtrada_idade_avaliacao)

crianca_03_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_03_filtrada_idade)
print(crianca_03_filtrada_idade_avaliacao)

crianca_04_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_04_filtrada_idade)
print(crianca_04_filtrada_idade_avaliacao)

crianca_05_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_05_filtrada_idade)
print(crianca_05_filtrada_idade_avaliacao)

crianca_06_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_06_filtrada_idade)
print(crianca_06_filtrada_idade_avaliacao)

crianca_07_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_07_filtrada_idade)
print(crianca_07_filtrada_idade_avaliacao)

crianca_08_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_08_filtrada_idade)
print(crianca_08_filtrada_idade_avaliacao)

crianca_09_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_09_filtrada_idade)
print(crianca_09_filtrada_idade_avaliacao)

crianca_10_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_10_filtrada_idade)
print(crianca_10_filtrada_idade_avaliacao)

crianca_11_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_11_filtrada_idade)
print(crianca_11_filtrada_idade_avaliacao)

crianca_12_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_12_filtrada_idade)
print(crianca_12_filtrada_idade_avaliacao)

crianca_13_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_13_filtrada_idade)
print(crianca_13_filtrada_idade_avaliacao)

crianca_14_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_14_filtrada_idade)
print(crianca_14_filtrada_idade_avaliacao)

crianca_15_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_15_filtrada_idade)
print(crianca_15_filtrada_idade_avaliacao)

crianca_16_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_16_filtrada_idade)
print(crianca_16_filtrada_idade_avaliacao)

crianca_17_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_17_filtrada_idade)
print(crianca_17_filtrada_idade_avaliacao)

crianca_18_filtrada_idade_avaliacao = filtro_crianca_avaliacao(crianca_18_filtrada_idade)
print(crianca_18_filtrada_idade_avaliacao)
# Out:
# {'id_crianca': '01', 'nome': 'junior', 'idade_meses': '4', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}]}
# {'id_crianca': '02', 'nome': 'paulo', 'idade_meses': '6', 'marcos': [{'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'ausente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '03', 'nome': 'maria', 'idade_meses': '4', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}]}
# {'id_crianca': '04', 'nome': 'julia', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'ausente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '05', 'nome': 'pedro', 'idade_meses': '3', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '06', 'nome': 'gabriel', 'idade_meses': '1', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}]}
# {'id_crianca': '07', 'nome': 'enzo', 'idade_meses': '6', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'ausente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'ausente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}]}
# {'id_crianca': '08', 'nome': 'naiara', 'idade_meses': '1', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}]}
# {'id_crianca': '09', 'nome': 'joao', 'idade_meses': '5', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'ausente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}]}
# {'id_crianca': '10', 'nome': 'kleber', 'idade_meses': '3', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '11', 'nome': 'melissa', 'idade_meses': '2', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'ausente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '12', 'nome': 'joana', 'idade_meses': '2', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'observa_rosto': {'id_marco': '02', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'ausente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}]}
# {'id_crianca': '13', 'nome': 'amanda', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '22', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'mostra_oque_quer': {'id_marco':  ...
# {'id_crianca': '14', 'nome': 'jose', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '22', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'mostra_oque_quer': {'id_marco': '2 ...
# {'id_crianca': '15', 'nome': 'janaina', 'idade_meses': '42', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'ausente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '22', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'mostra_oque_quer': {'id_marco':  ...
# {'id_crianca': '16', 'nome': 'geilson', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '22', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'mostra_oque_quer': {'id_marco': ...
# {'id_crianca': '17', 'nome': 'antonio', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '22', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'mostra_oque_quer': {'id_marco': ...
# {'id_crianca': '18', 'nome': 'joaquim', 'idade_meses': '72', 'marcos': [{'postura': {'id_marco': '01', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'reage_ao_som': {'id_marco': '03', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'eleva_cabeca': {'id_marco': '04', 'avaliacao': 'presente', 'registro_idade_mes': '1', 'limite_superior_faixa_etaria': '1', 'limite_inferior_faixa_etaria': '1'}}, {'sorrir_quando_estimulada': {'id_marco': '05', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'abre_as_maos': {'id_marco': '06', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'emite_sons': {'id_marco': '07', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'movimenta_membros': {'id_marco': '08', 'avaliacao': 'presente', 'registro_idade_mes': '2', 'limite_superior_faixa_etaria': '2', 'limite_inferior_faixa_etaria': '2'}}, {'responde_ativamente_contato_social': {'id_marco': '09', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'segura_objetos': {'id_marco': '10', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'emite_sons_ri_alto': {'id_marco': '11', 'avaliacao': 'presente', 'registro_idade_mes': '4', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'levanta_cabeça_antebraço_bruco': {'id_marco': '12', 'avaliacao': 'presente', 'registro_idade_mes': '3', 'limite_superior_faixa_etaria': '4', 'limite_inferior_faixa_etaria': '3'}}, {'busca_ativa_objetos': {'id_marco': '13', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'leva_objetos_boca': {'id_marco': '14', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'localiza_som': {'id_marco': '15', 'avaliacao': 'presente', 'registro_idade_mes': '5', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'muda_posicao_rolar': {'id_marco': '16', 'avaliacao': 'presente', 'registro_idade_mes': '6', 'limite_superior_faixa_etaria': '6', 'limite_inferior_faixa_etaria': '5'}}, {'brinca_esconde_achou': {'id_marco': '17', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'transfere_obejetos_mao_para_outra': {'id_marco': '18', 'avaliacao': 'presente', 'registro_idade_mes': '7', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'duplica_silabas': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '8', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'senta_sem_apoio': {'id_marco': '19', 'avaliacao': 'presente', 'registro_idade_mes': '9', 'limite_superior_faixa_etaria': '9', 'limite_inferior_faixa_etaria': '7'}}, {'imita_gestos': {'id_marco': '20', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'faz_pinca': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '11', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'produz_jargao': {'id_marco': '21', 'avaliacao': 'presente', 'registro_idade_mes': '12', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'anda_com_apoio': {'id_marco': '22', 'avaliacao': 'presente', 'registro_idade_mes': '10', 'limite_superior_faixa_etaria': '12', 'limite_inferior_faixa_etaria': '10'}}, {'mostra_oque_quer': {'id_marco': ...

# %% [markdown]
# ###Atualização da base de conhecimento

# %%
#Gera fatos dos dados das crianças
def gera_fatos_criancas(lista_criancas):
  fatos_criancas = []
  for c in lista_criancas:
    fato = f"crianca({c['nome']}_{c['id_crianca']}, {c['idade_meses']})"
    fatos_criancas.append(fato)
  return fatos_criancas

# %%
#Gera fatos dos marcos
def gera_fatos_marcos(crianca_filtrada_idade_avaliacao):
    fatos_marco_desenvolvimento = [] #lista para armazenar a string
    marcos_lista = []
    registro_idade_no_marco = []
    limite_superior_de_idade_do_marco = []

    marcos_crianca = crianca_filtrada_idade_avaliacao['marcos']
    for mrc_crianca in marcos_crianca:
        fato_marco_crianca = list(mrc_crianca.keys())[0]
        marco = fato_marco_crianca.split(')')[0]
        fato_marco = f"{marco}({crianca_filtrada_idade_avaliacao['nome']}_{crianca_filtrada_idade_avaliacao['id_crianca']}, {mrc_crianca[fato_marco_crianca]['avaliacao']}, {mrc_crianca[fato_marco_crianca]['registro_idade_mes']}, {mrc_crianca[fato_marco_crianca]['limite_superior_faixa_etaria']})"
        fatos_marco_desenvolvimento.append(fato_marco)
        marcos_lista.append(marco)
        registro_idade_no_marco.append(mrc_crianca[fato_marco_crianca]['registro_idade_mes'])
        limite_superior_de_idade_do_marco.append(mrc_crianca[fato_marco_crianca]['limite_superior_faixa_etaria'])

    return fatos_marco_desenvolvimento, marcos_lista,registro_idade_no_marco,limite_superior_de_idade_do_marco

# fatos_marco_desenvolvimento, marcos_lista = gera_fatos_marcos(crianca)

# %%
#Gera Regras dos marcos
def gera_regras_marcos(marcos_lista):
  regras_marcos = []
  regras_marcos_lista = list(OrderedDict.fromkeys(marcos_lista)) #retira duplicadas

  for rgr in regras_marcos_lista:
    regra_txt = f"{rgr}_presente(C) :- {rgr}(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)"
    regras_marcos.append(regra_txt)
  return regras_marcos

# %%
#Atualização da base de conhecimento / Fatos + Regras
def gerar_base_de_conhecimento(fatos_criancas, fatos_marco_desenvolvimento, regras_marcos):
  base_conhecimento = pl.KnowledgeBase("desenvolvimento_infantil")
  fatos_e_regras = fatos_criancas + fatos_marco_desenvolvimento + regras_marcos
  base_conhecimento(fatos_e_regras)
  print('------------------')
  print(base_conhecimento)
  print(*fatos_e_regras, sep='\n')
  print('------------------')
  return base_conhecimento

# base_conhecimento = gerar_base_de_conhecimento(fatos_criancas, fatos_marco_desenvolvimento, regras_marcos)

# %% [markdown]
# ### Aplicação de consultas sobre a base de conhecimento

# %%
def consulta_marcos_presentes_para_crianca(crianca_nome,marcos_lista,base_conhecimento):
  lista_retorno_consulta = []

  for m in marcos_lista:
    consulta = f"{m}_presente({crianca_nome})"
    resultado_consulta = base_conhecimento.query(pl.Expr(consulta))
    lista_retorno_consulta.append(resultado_consulta[0])

  return lista_retorno_consulta

def dev_adequado_crianca(crianca_nome,marcos_lista,base_conhecimento):
  resultados_marcos_lista = consulta_marcos_presentes_para_crianca(crianca_nome, marcos_lista,base_conhecimento)

  classificacao = False
  for r_mrc in resultados_marcos_lista:
    if r_mrc == "No":
      classificacao = False
      break
    else:
      classificacao = True

  return classificacao

# %% [markdown]
# ###Identificação de marcos ausentes, atrasos, adequados e em alertas

# %%
def identificar_marcos_ausentes(resultados_marcos_lista,marcos_lista):
  marcos_ausentes = []
  for i in range(len(resultados_marcos_lista)):
    if resultados_marcos_lista[i] == 'No':
      marcos_ausentes.append(marcos_lista[i])
  return marcos_ausentes

# %%
def identificar_indicacoes_alertas_atrasos(crianca, marcos_ausentes):
  marcos_crianca_selecionada = crianca['marcos']
  #print(list(marcos_crianca_selecionada[1].keys())[0])
  idade_crianca = int(crianca['idade_meses'])

  lista_indicacoes_marcos_alertas_atrasos = []
  for i in range(len(marcos_crianca_selecionada)):
    for j in range(len(marcos_ausentes)):
      if list(marcos_crianca_selecionada[i].keys())[0] == marcos_ausentes[j]:
        registro_idade_mes = marcos_crianca_selecionada[i][marcos_ausentes[j]]['registro_idade_mes']
        limite_superior_faixa_etaria = marcos_crianca_selecionada[i][marcos_ausentes[j]]['limite_superior_faixa_etaria']
        limite_inferior_faixa_etaria = marcos_crianca_selecionada[i][marcos_ausentes[j]]['limite_inferior_faixa_etaria']


        if (idade_crianca <= 1):
          lista_indicacoes_marcos_alertas_atrasos.append('atraso')

        else:
          if (idade_crianca >= int(limite_inferior_faixa_etaria) and idade_crianca <= int(limite_superior_faixa_etaria)):
            lista_indicacoes_marcos_alertas_atrasos.append('alerta')

          else:
            lista_indicacoes_marcos_alertas_atrasos.append('atraso')
  return lista_indicacoes_marcos_alertas_atrasos

# %%
def gerar_indicacoes_ad_at_al_marcos(resultados_marcos_lista, lista_indicacoes_marcos_alertas_atrasos):
  lista_indicacoes_marcos_adequado_alertas_atrasos = []

  if not lista_indicacoes_marcos_alertas_atrasos:
    for r_m in resultados_marcos_lista:
      lista_indicacoes_marcos_adequado_alertas_atrasos.append('AD')
  else:
    for r_m in resultados_marcos_lista:
      if r_m == 'No':

        if lista_indicacoes_marcos_alertas_atrasos[0] == 'atraso':
          abr_indicacao = 'AT'
        if lista_indicacoes_marcos_alertas_atrasos[0] == 'alerta':
          abr_indicacao = 'AL'

        lista_indicacoes_marcos_adequado_alertas_atrasos.append(abr_indicacao)
        lista_indicacoes_marcos_alertas_atrasos.pop(0)
      else:
        lista_indicacoes_marcos_adequado_alertas_atrasos.append('AD')

  return lista_indicacoes_marcos_adequado_alertas_atrasos

# %% [markdown]
# ### Funções que retornam as indicações de classificação da criança

# %%
def resposta_classificacao_geral(crianca,marcos_lista,lista_indicacoes_marcos_alertas_atrasos,base_conhecimento):
  is_dev_adequado = dev_adequado_crianca(f"{crianca['nome']}_{crianca['id_crianca']}", marcos_lista, base_conhecimento)

  if (is_dev_adequado):
    print("Desenvolvimento da criança está ADEQUADO.")
    return 'ADEQUADO'
  else:
    if "atraso" in lista_indicacoes_marcos_alertas_atrasos:
      print('Desenvolvimento da criança está ATRASADO.')
      return 'ATRASADO'
    else:
      print('Desenvolvimento da criança está em ALERTA.')
      return 'ALERTA'

#resposta_classificacao_geral(crianca,marcos_lista,lista_indicacoes_marcos_alertas_atrasos)

# %% [markdown]
# ###Uso das funções para classificação da criança

# %%
def classificacao_desenvolvimento_crianca(crianca):
  fatos_criancas = gera_fatos_criancas([crianca])
  fatos_marco_desenvolvimento, marcos_lista,registro_idade_no_marco,limite_superior_de_idade_do_marco = gera_fatos_marcos(crianca)
  regras_marcos =  gera_regras_marcos(marcos_lista)
  base_conhecimento = gerar_base_de_conhecimento(fatos_criancas, fatos_marco_desenvolvimento, regras_marcos)
  resultados_marcos_lista = consulta_marcos_presentes_para_crianca(f"{crianca['nome']}_{crianca['id_crianca']}", marcos_lista, base_conhecimento)
  print(resultados_marcos_lista)

  marcos_ausentes = identificar_marcos_ausentes(resultados_marcos_lista,marcos_lista)
  print(marcos_ausentes)

  lista_indicacoes_marcos_alertas_atrasos = identificar_indicacoes_alertas_atrasos(crianca, marcos_ausentes)
  print(lista_indicacoes_marcos_alertas_atrasos)

  classificacao_geral = resposta_classificacao_geral(crianca,marcos_lista,lista_indicacoes_marcos_alertas_atrasos,base_conhecimento)
  lista_indicacoes_marcos_adequado_alertas_atrasos = gerar_indicacoes_ad_at_al_marcos(resultados_marcos_lista, lista_indicacoes_marcos_alertas_atrasos)
  print(lista_indicacoes_marcos_adequado_alertas_atrasos)

  return classificacao_geral, marcos_lista, lista_indicacoes_marcos_adequado_alertas_atrasos, registro_idade_no_marco, limite_superior_de_idade_do_marco

# %% [markdown]
# ### Selecionar criança para diagnóstico

# %%
#Selecionar criança para a classificação do desenvolvimento com marcos já filtrados
crianca = crianca_17_filtrada_idade_avaliacao
idade_crianca = crianca['idade_meses']
_, marcos, ind_marcos, reg_idade_marco, limite_superior_idade_marco = classificacao_desenvolvimento_crianca(crianca)
# Out:
# ------------------
# KnowledgeBase: desenvolvimento_infantil
# crianca(antonio_17, 72)
# postura(antonio_17, presente, 1, 1)
# reage_ao_som(antonio_17, presente, 1, 1)
# eleva_cabeca(antonio_17, presente, 1, 1)
# sorrir_quando_estimulada(antonio_17, presente, 2, 2)
# abre_as_maos(antonio_17, presente, 2, 2)
# emite_sons(antonio_17, presente, 2, 2)
# movimenta_membros(antonio_17, presente, 2, 2)
# responde_ativamente_contato_social(antonio_17, presente, 3, 4)
# segura_objetos(antonio_17, presente, 3, 4)
# emite_sons_ri_alto(antonio_17, presente, 4, 4)
# levanta_cabeça_antebraço_bruco(antonio_17, presente, 3, 4)
# busca_ativa_objetos(antonio_17, presente, 5, 6)
# leva_objetos_boca(antonio_17, presente, 5, 6)
# localiza_som(antonio_17, presente, 5, 6)
# muda_posicao_rolar(antonio_17, presente, 6, 6)
# brinca_esconde_achou(antonio_17, presente, 7, 9)
# transfere_obejetos_mao_para_outra(antonio_17, presente, 7, 9)
# duplica_silabas(antonio_17, presente, 8, 9)
# senta_sem_apoio(antonio_17, presente, 9, 9)
# imita_gestos(antonio_17, presente, 10, 12)
# faz_pinca(antonio_17, presente, 11, 12)
# produz_jargao(antonio_17, presente, 12, 12)
# anda_com_apoio(antonio_17, presente, 10, 12)
# mostra_oque_quer(antonio_17, presente, 14, 15)
# coloca_blocos_caneca(antonio_17, presente, 14, 15)
# diz_uma_palavra(antonio_17, presente, 15, 15)
# anda_sem_apoio(antonio_17, presente, 15, 15)
# usa_colher_garfo(antonio_17, presente, 16, 18)
# constroi_torre_dois_cubos(antonio_17, presente, 17, 18)
# fala_tres_palavras(antonio_17, presente, 17, 18)
# anda_para_tras(antonio_17, presente, 18, 18)
# tira_roupa(antonio_17, presente, 19, 24)
# constroi_torre_tres_cubos(antonio_17, presente, 23, 24)
# aponta_duas_figuras(antonio_17, presente, 23, 24)
# chuta_bola(antonio_17, presente, 24, 24)
# veste_se_com_supervisao(antonio_17, presente, 26, 30)
# constroi_torre_seis_cubos(antonio_17, presente, 28, 30)
# frases_com_duas_palavras(antonio_17, presente, 29, 30)
# pula_ambos_pes(antonio_17, presente, 30, 30)
# brinca_outras_criancas(antonio_17, presente, 32, 36)
# imita_desenho_linha(antonio_17, presente, 33, 36)
# reconhece_duas_acoes(antonio_17, presente, 36, 36)
# arremessa_bola(antonio_17, presente, 35, 36)
# veste_uma_camiseta(antonio_17, presente, 38, 42)
# move_polegar_mao_fechada(antonio_17, presente, 39, 42)
# compreende_dois_adjetivos(antonio_17, presente, 38, 42)
# equilibra_em_cada_pe_por_um_segundo(antonio_17, presente, 42, 42)
# emparelha_cores(antonio_17, presente, 43, 48)
# copia_circulos(antonio_17, presente, 44, 48)
# fala_clara_compreencivel(antonio_17, presente, 46, 48)
# pula_em_um_pe_so(antonio_17, presente, 46, 48)
# veste_se_sem_ajuda(antonio_17, presente, 49, 54)
# copia_cruz(antonio_17, presente, 51, 54)
# compreende_quatro_preposicoes(antonio_17, presente, 52, 54)
# equilibra_em_cada_pe_por_tres_segundo(antonio_17, presente, 53, 54)
# escova_dentes_sem_ajuda(antonio_17, presente, 55, 60)
# aponta_linha_mais_comprida(antonio_17, presente, 56, 60)
# define_cinco_palavras(antonio_17, presente, 58, 60)
# equilibra_em_cada_pe_por_cinco_segundo(antonio_17, presente, 59, 60)
# brinca_de_faz_de_conta_com_criancas(antonio_17, presente, 61, 66)
# desenha_pessoa_com_seis_partes(antonio_17, presente, 63, 66)
# faz_analogia(antonio_17, presente, 64, 66)
# marcha_ponta_calcanhar(antonio_17, presente, 65, 66)
# aceita_segue_regras_nos_jogos_de_mesa(antonio_17, presente, 67, 72)
# copia_um_quadrado(antonio_17, ausente, 68, 72)
# define_sete_palavras(antonio_17, presente, 70, 72)
# equilibra_em_cada_pe_por_sete_segundo(antonio_17, presente, 71, 72)
# postura_presente(C) :- postura(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# reage_ao_som_presente(C) :- reage_ao_som(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# eleva_cabeca_presente(C) :- eleva_cabeca(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# sorrir_quando_estimulada_presente(C) :- sorrir_quando_estimulada(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# abre_as_maos_presente(C) :- abre_as_maos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# emite_sons_presente(C) :- emite_sons(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# movimenta_membros_presente(C) :- movimenta_membros(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# responde_ativamente_contato_social_presente(C) :- responde_ativamente_contato_social(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# segura_objetos_presente(C) :- segura_objetos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# emite_sons_ri_alto_presente(C) :- emite_sons_ri_alto(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# levanta_cabeça_antebraço_bruco_presente(C) :- levanta_cabeça_antebraço_bruco(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# busca_ativa_objetos_presente(C) :- busca_ativa_objetos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# leva_objetos_boca_presente(C) :- leva_objetos_boca(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# localiza_som_presente(C) :- localiza_som(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# muda_posicao_rolar_presente(C) :- muda_posicao_rolar(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# brinca_esconde_achou_presente(C) :- brinca_esconde_achou(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# transfere_obejetos_mao_para_outra_presente(C) :- transfere_obejetos_mao_para_outra(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# duplica_silabas_presente(C) :- duplica_silabas(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# senta_sem_apoio_presente(C) :- senta_sem_apoio(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# imita_gestos_presente(C) :- imita_gestos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# faz_pinca_presente(C) :- faz_pinca(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# produz_jargao_presente(C) :- produz_jargao(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# anda_com_apoio_presente(C) :- anda_com_apoio(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# mostra_oque_quer_presente(C) :- mostra_oque_quer(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# coloca_blocos_caneca_presente(C) :- coloca_blocos_caneca(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# diz_uma_palavra_presente(C) :- diz_uma_palavra(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# anda_sem_apoio_presente(C) :- anda_sem_apoio(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# usa_colher_garfo_presente(C) :- usa_colher_garfo(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# constroi_torre_dois_cubos_presente(C) :- constroi_torre_dois_cubos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# fala_tres_palavras_presente(C) :- fala_tres_palavras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# anda_para_tras_presente(C) :- anda_para_tras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# tira_roupa_presente(C) :- tira_roupa(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# constroi_torre_tres_cubos_presente(C) :- constroi_torre_tres_cubos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# aponta_duas_figuras_presente(C) :- aponta_duas_figuras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# chuta_bola_presente(C) :- chuta_bola(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# veste_se_com_supervisao_presente(C) :- veste_se_com_supervisao(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# constroi_torre_seis_cubos_presente(C) :- constroi_torre_seis_cubos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# frases_com_duas_palavras_presente(C) :- frases_com_duas_palavras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# pula_ambos_pes_presente(C) :- pula_ambos_pes(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# brinca_outras_criancas_presente(C) :- brinca_outras_criancas(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# imita_desenho_linha_presente(C) :- imita_desenho_linha(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# reconhece_duas_acoes_presente(C) :- reconhece_duas_acoes(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# arremessa_bola_presente(C) :- arremessa_bola(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# veste_uma_camiseta_presente(C) :- veste_uma_camiseta(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# move_polegar_mao_fechada_presente(C) :- move_polegar_mao_fechada(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# compreende_dois_adjetivos_presente(C) :- compreende_dois_adjetivos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# equilibra_em_cada_pe_por_um_segundo_presente(C) :- equilibra_em_cada_pe_por_um_segundo(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# emparelha_cores_presente(C) :- emparelha_cores(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# copia_circulos_presente(C) :- copia_circulos(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# fala_clara_compreencivel_presente(C) :- fala_clara_compreencivel(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# pula_em_um_pe_so_presente(C) :- pula_em_um_pe_so(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# veste_se_sem_ajuda_presente(C) :- veste_se_sem_ajuda(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# copia_cruz_presente(C) :- copia_cruz(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# compreende_quatro_preposicoes_presente(C) :- compreende_quatro_preposicoes(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# equilibra_em_cada_pe_por_tres_segundo_presente(C) :- equilibra_em_cada_pe_por_tres_segundo(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# escova_dentes_sem_ajuda_presente(C) :- escova_dentes_sem_ajuda(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# aponta_linha_mais_comprida_presente(C) :- aponta_linha_mais_comprida(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# define_cinco_palavras_presente(C) :- define_cinco_palavras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# equilibra_em_cada_pe_por_cinco_segundo_presente(C) :- equilibra_em_cada_pe_por_cinco_segundo(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# brinca_de_faz_de_conta_com_criancas_presente(C) :- brinca_de_faz_de_conta_com_criancas(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# desenha_pessoa_com_seis_partes_presente(C) :- desenha_pessoa_com_seis_partes(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# faz_analogia_presente(C) :- faz_analogia(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# marcha_ponta_calcanhar_presente(C) :- marcha_ponta_calcanhar(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# aceita_segue_regras_nos_jogos_de_mesa_presente(C) :- aceita_segue_regras_nos_jogos_de_mesa(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# copia_um_quadrado_presente(C) :- copia_um_quadrado(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# define_sete_palavras_presente(C) :- define_sete_palavras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# equilibra_em_cada_pe_por_sete_segundo_presente(C) :- equilibra_em_cada_pe_por_sete_segundo(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# ------------------
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes']
# ['copia_um_quadrado']
# ['alerta']
# Desenvolvimento da criança está em ALERTA.
# ['AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AL', 'AD', 'AD']

# %% [markdown]
# ### Filtragem de dados

# %%
def filtrar_faixa_etaria_anterior_atual(crianca):
    lista_crianca_filtrada_marcos_atual = []

    crianca_filtrada = crianca.copy()
    idade_meses = int(crianca_filtrada['idade_meses'])

    marcos_adicionados = set()  # Conjunto para armazenar os marcos já adicionados

    for marco in crianca_filtrada['marcos']:
        chave_marco = list(marco.keys())[0]
        limite_superior = int(marco[chave_marco]['limite_superior_faixa_etaria'])
        limite_inferior = int(marco[chave_marco]['limite_inferior_faixa_etaria'])

        # Faixa etária atual
        if limite_inferior <= idade_meses <= limite_superior:

            # Adiciona os marcos da faixa etária anterior
            limite_inferior_anterior = limite_inferior - 1
            for marco_anterior in crianca_filtrada['marcos']:
                chave_marco_anterior = list(marco_anterior.keys())[0]
                limite_superior_anterior = int(marco_anterior[chave_marco_anterior]['limite_superior_faixa_etaria'])
                limite_inferior_anterior_marco = int(marco_anterior[chave_marco_anterior]['limite_inferior_faixa_etaria'])

                if limite_inferior_anterior_marco <= limite_inferior_anterior <= limite_superior_anterior:
                    chave_marco_anterior = list(marco_anterior.keys())[0]
                    if chave_marco_anterior not in marcos_adicionados:  # Verifica se o marco já foi adicionado
                        lista_crianca_filtrada_marcos_atual.append(marco_anterior)
                        marcos_adicionados.add(chave_marco_anterior)  # Adiciona o marco ao conjunto de marcos já adicionados

            lista_crianca_filtrada_marcos_atual.append(marco)

    crianca_filtrada['marcos'] = lista_crianca_filtrada_marcos_atual
    return crianca_filtrada

# %%
#Selecionar criança para a classificação do desenvolvimento com marcos já filtrados
crianca_filtrada = filtrar_faixa_etaria_anterior_atual(crianca)
class_geral, _, _, _, _ = classificacao_desenvolvimento_crianca(crianca_filtrada)
# Out:
# ------------------
# KnowledgeBase: desenvolvimento_infantil
# crianca(antonio_17, 72)
# brinca_de_faz_de_conta_com_criancas(antonio_17, presente, 61, 66)
# desenha_pessoa_com_seis_partes(antonio_17, presente, 63, 66)
# faz_analogia(antonio_17, presente, 64, 66)
# marcha_ponta_calcanhar(antonio_17, presente, 65, 66)
# aceita_segue_regras_nos_jogos_de_mesa(antonio_17, presente, 67, 72)
# copia_um_quadrado(antonio_17, ausente, 68, 72)
# define_sete_palavras(antonio_17, presente, 70, 72)
# equilibra_em_cada_pe_por_sete_segundo(antonio_17, presente, 71, 72)
# brinca_de_faz_de_conta_com_criancas_presente(C) :- brinca_de_faz_de_conta_com_criancas(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# desenha_pessoa_com_seis_partes_presente(C) :- desenha_pessoa_com_seis_partes(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# faz_analogia_presente(C) :- faz_analogia(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# marcha_ponta_calcanhar_presente(C) :- marcha_ponta_calcanhar(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# aceita_segue_regras_nos_jogos_de_mesa_presente(C) :- aceita_segue_regras_nos_jogos_de_mesa(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# copia_um_quadrado_presente(C) :- copia_um_quadrado(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# define_sete_palavras_presente(C) :- define_sete_palavras(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# equilibra_em_cada_pe_por_sete_segundo_presente(C) :- equilibra_em_cada_pe_por_sete_segundo(C ,presente, Reg_idade_marco, Limite_superi_faixa),crianca(C, Idade), (Reg_idade_marco <= Limite_superi_faixa and Idade >= Reg_idade_marco)
# ------------------
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes']
# ['copia_um_quadrado']
# ['alerta']
# Desenvolvimento da criança está em ALERTA.
# ['AD', 'AD', 'AD', 'AD', 'AD', 'AL', 'AD', 'AD']

# %%
nome_crianca = crianca_filtrada['nome']

print("Nome da criança:\n",nome_crianca)
print("Idade da criança:\n",idade_crianca)
print("A classificação geral da criança:\n",class_geral)
print("A marcos da criança:\n",marcos)
print("Indicadores para a classificação geral da criança:\n",ind_marcos)
print("Idade onde foi registrado cada marco da criança:\n",reg_idade_marco)
print("Limite de superior de cada marco:\n",limite_superior_idade_marco)
print("---------")

indices_marcos_atingidos = []
for i in range(len(ind_marcos)):
  if ind_marcos[i] == "AD":
    indices_marcos_atingidos.append(i)

indices_marcos_atingidos_at = []
for i in range(len(ind_marcos)):
  if ind_marcos[i] == "AT":
    indices_marcos_atingidos_at.append(i)

indices_marcos_atingidos_al = []
for i in range(len(ind_marcos)):
  if ind_marcos[i] == "AL":
    indices_marcos_atingidos_al.append(i)

idade_marcos_atingidos = [reg_idade_marco[i] for i in indices_marcos_atingidos]
marcos_atingidos = [marcos[i] for i in indices_marcos_atingidos]

idade_marcos_atingidos_at = [reg_idade_marco[i] for i in indices_marcos_atingidos_at]
marcos_atingidos_at = [marcos[i] for i in indices_marcos_atingidos_at]

idade_marcos_atingidos_al = [reg_idade_marco[i] for i in indices_marcos_atingidos_al]
marcos_atingidos_al = [marcos[i] for i in indices_marcos_atingidos_al]

print("Idade dos marcos atingidos:\n",idade_marcos_atingidos)
print("Marcos atingidos:\n",marcos_atingidos)
print("Quantidade de Marcos Atingidos", len(idade_marcos_atingidos))
# Out:
# Nome da criança:
#  antonio
# Idade da criança:
#  72
# A classificação geral da criança:
#  ALERTA
# A marcos da criança:
#  ['postura', 'reage_ao_som', 'eleva_cabeca', 'sorrir_quando_estimulada', 'abre_as_maos', 'emite_sons', 'movimenta_membros', 'responde_ativamente_contato_social', 'segura_objetos', 'emite_sons_ri_alto', 'levanta_cabeça_antebraço_bruco', 'busca_ativa_objetos', 'leva_objetos_boca', 'localiza_som', 'muda_posicao_rolar', 'brinca_esconde_achou', 'transfere_obejetos_mao_para_outra', 'duplica_silabas', 'senta_sem_apoio', 'imita_gestos', 'faz_pinca', 'produz_jargao', 'anda_com_apoio', 'mostra_oque_quer', 'coloca_blocos_caneca', 'diz_uma_palavra', 'anda_sem_apoio', 'usa_colher_garfo', 'constroi_torre_dois_cubos', 'fala_tres_palavras', 'anda_para_tras', 'tira_roupa', 'constroi_torre_tres_cubos', 'aponta_duas_figuras', 'chuta_bola', 'veste_se_com_supervisao', 'constroi_torre_seis_cubos', 'frases_com_duas_palavras', 'pula_ambos_pes', 'brinca_outras_criancas', 'imita_desenho_linha', 'reconhece_duas_acoes', 'arremessa_bola', 'veste_uma_camiseta', 'move_polegar_mao_fechada', 'compreende_dois_adjetivos', 'equilibra_em_cada_pe_por_um_segundo', 'emparelha_cores', 'copia_circulos', 'fala_clara_compreencivel', 'pula_em_um_pe_so', 'veste_se_sem_ajuda', 'copia_cruz', 'compreende_quatro_preposicoes', 'equilibra_em_cada_pe_por_tres_segundo', 'escova_dentes_sem_ajuda', 'aponta_linha_mais_comprida', 'define_cinco_palavras', 'equilibra_em_cada_pe_por_cinco_segundo', 'brinca_de_faz_de_conta_com_criancas', 'desenha_pessoa_com_seis_partes', 'faz_analogia', 'marcha_ponta_calcanhar', 'aceita_segue_regras_nos_jogos_de_mesa', 'copia_um_quadrado', 'define_sete_palavras', 'equilibra_em_cada_pe_por_sete_segundo']
# Indicadores para a classificação geral da criança:
#  ['AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AD', 'AL', 'AD', 'AD']
# Idade onde foi registrado cada marco da criança:
#  ['1', '1', '1', '2', '2', '2', '2', '3', '3', '4', '3', '5', '5', '5', '6', '7', '7', '8', '9', '10', '11', '12', '10', '14', '14', '15', '15', '16', '17', '17', '18', '19', '23', '23', '24', '26', '28', '29', '30', '32', '33', '36', '35', '38', '39', '38', '42', '43', '44', '46', '46', '49', '51', '52', '53', '55', '56', '58', '59', '61', '63', '64', '65', '67', '68', '70', '71']
# Limite de superior de cada marco:
#  ['1', '1', '1', '2', '2', '2', '2', '4', '4', '4', '4', '6', '6', '6', '6', '9', '9', '9', '9', '12', '12', '12', '12', '15', '15', '15', '15', '18', '18', '18', '18', '24', '24', '24', '24', '30', '30', '30', '30', '36', '36', '36', '36', '42', '42', '42', '42', '48', '48', '48', '48', '54', '54', '54', '54', '60', '60', '60', '60', '66', '66', '66', '66', '72', '72', '72', '72']
# ---------
# Idade dos marcos atingidos:
#  ['1', '1', '1', '2', '2', '2', '2', '3', '3', '4', '3', '5', '5', '5', '6', '7', '7', '8', '9', '10', '11', '12', '10', '14', '14', '15', '15', '16', '17', '17', '18', '19', '23', '23', '24', '26', '28', '29', '30', '32', '33', '36', '35', '38', '39', '38', '42', '43', '44', '46', '46', '49', '51', '52', '53', '55', '56', '58', '59', '61', '63', '64', '65', '67', '70', '71']
# Marcos atingidos:
#  ['postura', 'reage_ao_som', 'eleva_cabeca', 'sorrir_quando_estimulada', 'abre_as_maos', 'emite_sons', 'movimenta_membros', 'responde_ativamente_contato_social', 'segura_objetos', 'emite_sons_ri_alto', 'levanta_cabeça_antebraço_bruco', 'busca_ativa_objetos', 'leva_objetos_boca', 'localiza_som', 'muda_posicao_rolar', 'brinca_esconde_achou', 'transfere_obejetos_mao_para_outra', 'duplica_silabas', 'senta_sem_apoio', 'imita_gestos', 'faz_pinca', 'produz_jargao', 'anda_com_apoio', 'mostra_oque_quer', 'coloca_blocos_caneca', 'diz_uma_palavra', 'anda_sem_apoio', 'usa_colher_garfo', 'constroi_torre_dois_cubos', 'fala_tres_palavras', 'anda_para_tras', 'tira_roupa', 'constroi_torre_tres_cubos', 'aponta_duas_figuras', 'chuta_bola', 'veste_se_com_supervisao', 'constroi_torre_seis_cubos', 'frases_com_duas_palavras', 'pula_ambos_pes', 'brinca_outras_criancas', 'imita_desenho_linha', 'reconhece_duas_acoes', 'arremessa_bola', 'veste_uma_camiseta', 'move_polegar_mao_fechada', 'compreende_dois_adjetivos', 'equilibra_em_cada_pe_por_um_segundo', 'emparelha_cores', 'copia_circulos', 'fala_clara_compreencivel', 'pula_em_um_pe_so', 'veste_se_sem_ajuda', 'copia_cruz', 'compreende_quatro_preposicoes', 'equilibra_em_cada_pe_por_tres_segundo', 'escova_dentes_sem_ajuda', 'aponta_linha_mais_comprida', 'define_cinco_palavras', 'equilibra_em_cada_pe_por_cinco_segundo', 'brinca_de_faz_de_conta_com_criancas', 'desenha_pessoa_com_seis_partes', 'faz_analogia', 'marcha_ponta_calcanhar', 'aceita_segue_regras_nos_jogos_de_mesa', 'define_sete_palavras', 'equilibra_em_cada_pe_por_sete_segundo']
# Quantidade de Marcos Atingidos 66

# %% [markdown]
# ### Gráfico de acompanhamento do desenvolvimento

# %%
import matplotlib.pyplot as plt

def gerar_grafico_progresso(crianca_filtrada):
    plt.figure(figsize=(20, 12))
    plt.plot(idade_marcos_atingidos, marcos_atingidos, marker='o', linestyle='None', color='b')
    plt.plot(idade_marcos_atingidos_al, marcos_atingidos_al, marker='o', linestyle='None', color='y')
    plt.plot(idade_marcos_atingidos_at, marcos_atingidos_at, marker='o', linestyle='None', color='r')
    plt.xlabel('Idade (meses)')
    plt.ylabel('Marcos de Desenvolvimento')
    plt.title(f'{nome_crianca} - Desenvolvimento: {class_geral}')
    plt.grid(True)
    plt.legend(loc='upper left', bbox_to_anchor= (1.0, 1.1), labels=['Adequado', 'Alerta', 'Atraso'])
    plt.show()

# %% [markdown]
# ### Gerar gráfico

# %%
gerar_grafico_progresso(crianca_filtrada)
